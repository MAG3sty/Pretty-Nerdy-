# %%
import pandas as pd

# %%
esi = pd.read_csv ("C:/Users/Taitana/Desktop/Employee Satisfaction Index.csv")

# %%
esi
# Out:
#      Unnamed: 0    emp_id  age        Dept location education  \
# 0             0    HR8270   28          HR   Suburb        PG
# 1             1  TECH1860   50  Technology   Suburb        PG
# 2             2  TECH6390   43  Technology   Suburb        UG
# 3             3   SAL6191   44       Sales     City        PG
# 4             4    HR6734   33          HR     City        UG
# ..          ...       ...  ...         ...      ...       ...
# 495         495    HR5330   49          HR   Suburb        PG
# 496         496  TECH9010   24  Technology   Suburb        UG
# 497         497   MKT7801   34   Marketing     City        PG
# 498         498  TECH5846   26  Technology     City        UG
# 499         499  TECH7731   26  Technology     City        UG
#
#        recruitment_type  job_level  rating  onsite  awards  certifications  \
# 0              Referral          5       2       0       1               0
# 1               Walk-in          3       5       1       2               1
# 2              Referral          4       1       0       2               0
# 3             On-Campus          2       3       1       0               0
# 4    Recruitment Agency          2       1       0       5               0
# ..                  ...        ...     ...     ...     ...             ...
# 495           On-Campus          2       5       0       6               0
# 496            Referral          2       4       0       2               0
# 497           On-Campus          1       3       0       2               0
# 498           On-Campus          2       1       1       1               1
# 499  Recruitment Agency          3       4       0       3               0
#
#      salary  satisfied
# 0     86750          1
# 1     42419          0
# 2     65715          0
# 3     29805          1
# 4     29805          1
# ..      ...        ...
# 495   29805          1
# 496   29805          0
# 497   24076          1
# 498   29805          0
# 499   42419          0
#
# [500 rows x 14 columns]

# %%
esi.head()
# Out:
#    Unnamed: 0    emp_id  age        Dept location education  \
# 0           0    HR8270   28          HR   Suburb        PG
# 1           1  TECH1860   50  Technology   Suburb        PG
# 2           2  TECH6390   43  Technology   Suburb        UG
# 3           3   SAL6191   44       Sales     City        PG
# 4           4    HR6734   33          HR     City        UG
#
#      recruitment_type  job_level  rating  onsite  awards  certifications  \
# 0            Referral          5       2       0       1               0
# 1             Walk-in          3       5       1       2               1
# 2            Referral          4       1       0       2               0
# 3           On-Campus          2       3       1       0               0
# 4  Recruitment Agency          2       1       0       5               0
#
#    salary  satisfied
# 0   86750          1
# 1   42419          0
# 2   65715          0
# 3   29805          1
# 4   29805          1

# %%
#Are employees satisfied with their work life?
#variables (salary, depart, job level, satisfied,rating)
#dropping columns (errors are due to columns being dropped per prev coding)

# %%
esi.drop(['Unnamed: 0','emp_id'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 esi.drop(['Unnamed: 0','emp_id'],axis=1,inplace=True)
#
# File C:\Python3\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File C:\Python3\lib\site-packages\pandas\core\frame.py:5391, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5243 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5244 def drop(  # type: ignore[override]
#    5245     self,
#    (...)
#    5252     errors: IgnoreRaise = "raise",
#    5253 ) -> DataFrame | None:
#    5254     """
#    5255     Drop specified labels from rows or columns.
#    5256
#    (...)
#    5389             weight  1.0     0.8
#    5390     """
# -> 5391     return super().drop(
#    5392         labels=labels,
#    5393         axis=axis,
#    5394         index=index,
#    5395         columns=columns,
#    5396         level=level,
#    5397         inplace=inplace,
#    5398         errors=errors,
#    5399     )
#
# File C:\Python3\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File C:\Python3\lib\site-packages\pandas\core\generic.py:4510, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4508 for axis, labels in axes.items():
#    4509     if labels is not None:
# -> 4510         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4512 if inplace:
#    4513     self._update_inplace(obj)
#
# File C:\Python3\lib\site-packages\pandas\core\generic.py:4551, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4549         new_axis = axis.drop(labels, level=level, errors=errors)
#    4550     else:
# -> 4551         new_axis = axis.drop(labels, errors=errors)
#    4552     indexer = axis.get_indexer(new_axis)
#    4554 # Case for non-unique axis
#    4555 else:
#
# File C:\Python3\lib\site-packages\pandas\core\indexes\base.py:6972, in Index.drop(self, labels, errors)
#    6970 if mask.any():
#    6971     if errors != "ignore":
# -> 6972         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6973     indexer = indexer[~mask]
#    6974 return self.delete(indexer)
#
# KeyError: "['Unnamed: 0', 'emp_id'] not found in axis"

# %%
esi
# Out:
#      age        Dept location education    recruitment_type  job_level  \
# 0     28          HR   Suburb        PG            Referral          5
# 1     50  Technology   Suburb        PG             Walk-in          3
# 2     43  Technology   Suburb        UG            Referral          4
# 3     44       Sales     City        PG           On-Campus          2
# 4     33          HR     City        UG  Recruitment Agency          2
# ..   ...         ...      ...       ...                 ...        ...
# 495   49          HR   Suburb        PG           On-Campus          2
# 496   24  Technology   Suburb        UG            Referral          2
# 497   34   Marketing     City        PG           On-Campus          1
# 498   26  Technology     City        UG           On-Campus          2
# 499   26  Technology     City        UG  Recruitment Agency          3
#
#      rating  onsite  awards  certifications  salary  satisfied satisfiedR
# 0         2       0       1               0   86750          1       None
# 1         5       1       2               1   42419          0       None
# 2         1       0       2               0   65715          0       None
# 3         3       1       0               0   29805          1       None
# 4         1       0       5               0   29805          1       None
# ..      ...     ...     ...             ...     ...        ...        ...
# 495       5       0       6               0   29805          1       None
# 496       4       0       2               0   29805          0       None
# 497       3       0       2               0   24076          1       None
# 498       1       1       1               1   29805          0       None
# 499       4       0       3               0   42419          0       None
#
# [500 rows x 13 columns]

# %%
esi.drop(['location','awards'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 esi.drop(['location','awards'],axis=1,inplace=True)
#
# File C:\Python3\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File C:\Python3\lib\site-packages\pandas\core\frame.py:5391, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5243 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5244 def drop(  # type: ignore[override]
#    5245     self,
#    (...)
#    5252     errors: IgnoreRaise = "raise",
#    5253 ) -> DataFrame | None:
#    5254     """
#    5255     Drop specified labels from rows or columns.
#    5256
#    (...)
#    5389             weight  1.0     0.8
#    5390     """
# -> 5391     return super().drop(
#    5392         labels=labels,
#    5393         axis=axis,
#    5394         index=index,
#    5395         columns=columns,
#    5396         level=level,
#    5397         inplace=inplace,
#    5398         errors=errors,
#    5399     )
#
# File C:\Python3\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File C:\Python3\lib\site-packages\pandas\core\generic.py:4510, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4508 for axis, labels in axes.items():
#    4509     if labels is not None:
# -> 4510         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4512 if inplace:
#    4513     self._update_inplace(obj)
#
# File C:\Python3\lib\site-packages\pandas\core\generic.py:4551, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4549         new_axis = axis.drop(labels, level=level, errors=errors)
#    4550     else:
# -> 4551         new_axis = axis.drop(labels, errors=errors)
#    4552     indexer = axis.get_indexer(new_axis)
#    4554 # Case for non-unique axis
#    4555 else:
#
# File C:\Python3\lib\site-packages\pandas\core\indexes\base.py:6972, in Index.drop(self, labels, errors)
#    6970 if mask.any():
#    6971     if errors != "ignore":
# -> 6972         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6973     indexer = indexer[~mask]
#    6974 return self.delete(indexer)
#
# KeyError: "['location', 'awards'] not found in axis"

# %%
esi.drop(['certifications','onsite'],axis=1,inplace=True)

# %%
esi
# Out:
#      age        Dept education    recruitment_type  job_level  rating  salary  \
# 0     28          HR        PG            Referral          5       2   86750
# 1     50  Technology        PG             Walk-in          3       5   42419
# 2     43  Technology        UG            Referral          4       1   65715
# 3     44       Sales        PG           On-Campus          2       3   29805
# 4     33          HR        UG  Recruitment Agency          2       1   29805
# ..   ...         ...       ...                 ...        ...     ...     ...
# 495   49          HR        PG           On-Campus          2       5   29805
# 496   24  Technology        UG            Referral          2       4   29805
# 497   34   Marketing        PG           On-Campus          1       3   24076
# 498   26  Technology        UG           On-Campus          2       1   29805
# 499   26  Technology        UG  Recruitment Agency          3       4   42419
#
#      satisfied satisfiedR
# 0            1       None
# 1            0       None
# 2            0       None
# 3            1       None
# 4            1       None
# ..         ...        ...
# 495          1       None
# 496          0       None
# 497          1       None
# 498          0       None
# 499          0       None
#
# [500 rows x 9 columns]

# %%
#transposing data to have each column labeled by the salary

# %%
esi2 = esi.set_index('salary').T

# %%
esi2
# Out:
# salary               86750       42419       65715      29805  \
# age                     28          50          43         44
# Dept                    HR  Technology  Technology      Sales
# education               PG          PG          UG         PG
# recruitment_type  Referral     Walk-in    Referral  On-Campus
# job_level                5           3           4          2
# rating                   2           5           1          3
# satisfied                1           0           0          1
# satisfiedR            None        None        None       None
#
# salary                         29805       42419       86750  \
# age                               33          40          26
# Dept                              HR  Purchasing  Purchasing
# education                         UG          UG          UG
# recruitment_type  Recruitment Agency    Referral    Referral
# job_level                          2           3           5
# rating                             1           3           5
# satisfied                          1           1           0
# satisfiedR                      None        None        None
#
# salary                         24076     42419       42419  ...  \
# age                               25        35          45  ...
# Dept                      Technology        HR  Technology  ...
# education                         UG        PG          PG  ...
# recruitment_type  Recruitment Agency  Referral    Referral  ...
# job_level                          1         3           3  ...
# rating                             1         4           3  ...
# satisfied                          0         1           0  ...
# satisfiedR                      None      None        None  ...
#
# salary                         65715       42419      42419      86750  \
# age                               47          23         33         41
# Dept                      Purchasing  Technology         HR  Marketing
# education                         UG          PG         UG         UG
# recruitment_type  Recruitment Agency   On-Campus  On-Campus    Walk-in
# job_level                          4           3          3          5
# rating                             4           1          5          4
# satisfied                          0           0          1          0
# satisfiedR                      None        None       None       None
#
# salary               42419      29805       29805      24076       29805  \
# age                     31         49          24         34          26
# Dept                 Sales         HR  Technology  Marketing  Technology
# education               PG         PG          UG         PG          UG
# recruitment_type  Referral  On-Campus    Referral  On-Campus   On-Campus
# job_level                3          2           2          1           2
# rating                   3          5           4          3           1
# satisfied                1          1           0          1           0
# satisfiedR            None       None        None       None        None
#
# salary                         42419
# age                               26
# Dept                      Technology
# education                         UG
# recruitment_type  Recruitment Agency
# job_level                          3
# rating                             4
# satisfied                          0
# satisfiedR                      None
#
# [8 rows x 500 columns]

# %%
#higher salaries have high job_levels

# %%
esi1 = esi.copy()                                # Create copy of DataFrame
esi1['satisfied'] = esi1['satisfied'].astype(bool)          # Transform integer to boolean
print(esi1)
# Out:
#      age        Dept education    recruitment_type  job_level  rating  salary  \
# 0     28          HR        PG            Referral          5       2   86750
# 1     50  Technology        PG             Walk-in          3       5   42419
# 2     43  Technology        UG            Referral          4       1   65715
# 3     44       Sales        PG           On-Campus          2       3   29805
# 4     33          HR        UG  Recruitment Agency          2       1   29805
# ..   ...         ...       ...                 ...        ...     ...     ...
# 495   49          HR        PG           On-Campus          2       5   29805
# 496   24  Technology        UG            Referral          2       4   29805
# 497   34   Marketing        PG           On-Campus          1       3   24076
# 498   26  Technology        UG           On-Campus          2       1   29805
# 499   26  Technology        UG  Recruitment Agency          3       4   42419
#
#      satisfied satisfiedR
# 0         True       None
# 1        False       None
# 2        False       None
# 3         True       None
# 4         True       None
# ..         ...        ...
# 495       True       None
# 496      False       None
# 497       True       None
# 498      False       None
# 499      False       None
#
# [500 rows x 9 columns]

# %%
#above dataframe 'esi1' has column ' satisfied' converted to true or false statements from '1' and '0' integers
